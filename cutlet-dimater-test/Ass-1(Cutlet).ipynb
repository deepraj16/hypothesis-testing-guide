# %% [markdown]
# # Problem statment

# %% [raw]
# 1.)	A F&B manager wants to determine whether there is any significant difference in the diameter of the cutlet between two units. A randomly selected sample of cutlets was collected from both units and measured? Analyze the data and draw inferences at 5% significance level. Please state the assumptions and tests that you carried out to check validity of the assumptions.

# %% [raw]
# two units, you can perform an independent
#
# t-test
# (also known as an unpaired t-test)
# at a 5% significance level.

# %% [raw]
# Step 1: Define Hypotheses
# Null Hypothesis (H₀): There is no significant difference in the mean diameter of cutlets between the two units.
# 𝐻0 :𝜇1=𝜇2
#
#
# Alternative Hypothesis (H₁): There is a significant difference in the mean diameter of cutlets between the two units.
#                 H0 : μ1!=μ2
#
# so we have to work on two tail test

# %%
import pandas as pd 
import numpy as np 
df=pd.read_csv("Cutlets.csv")

# %%
df=df.iloc[:35,:]

# %% [raw]
# Step 2: Assumptions to Check
# To perform an independent t-test, the following assumptions must be verified:
#
# 1)Independence: The samples from both units should be independent of each other.
# 2)Normality: The diameter of the cutlets should be normally distributed in both units.
# 3)Equal Variance (Homogeneity of Variance): The variances of both groups should be equal (can be tested using Levene’s test).

# %%
df.sample(4)
# Out:
#     Unit A  Unit B
# 26  7.2163  7.0133
# 30  6.7794  7.0992
# 5   7.3871  6.8110
# 34  6.9405  7.3875

# %% [raw]
# Step 3: Conduct Exploratory Data Analysis (EDA)
# Before performing the t-test, check the data distribution:
#
# 1)Summary Statistics: Check mean, median, variance, standard deviation.
# 2)Box Plot: Identify outliers.
# 3)Histogram/QQ Plot: Check for normality visually.
# 4)Shapiro-Wilk Test: Statistically test normality.
# 4)Levene’s Test (or F-test): Check variance equality.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.isnull().sum()
# Out:
# Unit A    0
# Unit B    0
# dtype: int64

# %%
df.shape
# Out:
# (35, 2)

# %%
df.describe()
# Out:
#           Unit A     Unit B
# count  35.000000  35.000000
# mean    7.019091   6.964297
# std     0.288408   0.343401
# min     6.437600   6.038000
# 25%     6.831500   6.753600
# 50%     6.943800   6.939900
# 75%     7.280550   7.195000
# max     7.516900   7.545900

# %%
ax=plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
sns.kdeplot(df,x='Unit A')

plt.subplot(1,2,2)
sns.kdeplot(df,x='Unit B')
# Out:
# <Axes: xlabel='Unit B', ylabel='Density'>

# %%
ax=plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
sns.boxplot(df,y='Unit A')

plt.subplot(1,2,2)
sns.boxplot(df,y='Unit B')
# Out:
# <Axes: ylabel='Unit B'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
#QQ Plot
# A Q-Q plot (Quantile-Quantile plot) is used to check whether a dataset follows a normal distribution.
# It plots the quantiles of the dataset against the theoretical quantiles of
# a normal distribution. If the points in the plot roughly follow a straight diagonal line, the data is normally distributed.

import scipy.stats as stats
import matplotlib.pyplot as plt
import statsmodels.api as sm

unit1 = df["Unit A"]
unit2 = df["Unit B"]

sm.qqplot(unit1, line='s')
plt.title("Q-Q Plot for Unit A")
plt.show()

sm.qqplot(unit2, line='s')
plt.title("Q-Q Plot for Unit B")
plt.show()

# %%
#nomal distrubion

# %%
nit1 = df["Unit A"]
unit2 = df["Unit B"]

# Check normality using Shapiro-Wilk test
print("Shapiro Test for Unit 1:", stats.shapiro(unit1))
print("Shapiro Test for Unit 2:", stats.shapiro(unit2))
# Out:
# Shapiro Test for Unit 1: ShapiroResult(statistic=0.9649459719657898, pvalue=0.31998491287231445)
# Shapiro Test for Unit 2: ShapiroResult(statistic=0.9727305769920349, pvalue=0.5225146412849426)

# %%
print("Levene’s Test:", stats.levene(unit1, unit2))
t_stat, p_value = stats.ttest_ind(unit1, unit2, equal_var=True)  # Use equal_var=False if variances are unequal
# Out:
# Levene’s Test: LeveneResult(statistic=0.6650897638632386, pvalue=0.4176162212502553)

# %%
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: 0.7228688704678063
# p-value: 0.4722394724599501

# %%
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference in cutlet diameter.")
else:
    print("Fail to reject the null hypothesis: No significant difference in cutlet diameter.")
# Out:
# Fail to reject the null hypothesis: No significant difference in cutlet diameter.

# %% [markdown]
# # Conclusion

# %% [raw]
# Based on the p-value, conclude whether the difference in cutlet diameters between the two units is statistically significant.
# No signifcat diffrence in cutlet
